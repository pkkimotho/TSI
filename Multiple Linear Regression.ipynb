# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split as tts
data = {
    "body_mass": [174.4,164.4,244.2,154.6,181.7,201.7,152.8,163.2,145.2,137.2,241.9,191.1,232,145.3,161.1,209.7,146.4,144,232.6,224.1,166.5],
    "bmi_index": [68.5,45.2,91.3,47.8,46.9,66.1,49.5,52,48.9,38.4,87.9,72.8,88.4,42.9,52.5,85.7,41.3,51.7,89.6,82.7,52.3],
    "blood_sugar_level": [16.7,16.8,18.2,16.3,17.3,18.2,15.9,17.2,16.6,16,18.3,17.1,17.4,15.8,17.8,18.4,16.5,16.3,18.1,19.1,16]
}
data = pd.DataFrame(data)
data.head(12)
# Out:
#     body_mass  bmi_index  blood_sugar_level
# 0       174.4       68.5               16.7
# 1       164.4       45.2               16.8
# 2       244.2       91.3               18.2
# 3       154.6       47.8               16.3
# 4       181.7       46.9               17.3
# 5       201.7       66.1               18.2
# 6       152.8       49.5               15.9
# 7       163.2       52.0               17.2
# 8       145.2       48.9               16.6
# 9       137.2       38.4               16.0
# 10      241.9       87.9               18.3
# 11      191.1       72.8               17.1

# %%
data.corr
# Out:
# <bound method DataFrame.corr of     body_mass  bmi_index  blood_sugar_level
# 0       174.4       68.5               16.7
# 1       164.4       45.2               16.8
# 2       244.2       91.3               18.2
# 3       154.6       47.8               16.3
# 4       181.7       46.9               17.3
# 5       201.7       66.1               18.2
# 6       152.8       49.5               15.9
# 7       163.2       52.0               17.2
# 8       145.2       48.9               16.6
# 9       137.2       38.4               16.0
# 10      241.9       87.9               18.3
# 11      191.1       72.8               17.1
# 12      232.0       88.4               17.4
# 13      145.3       42.9               15.8
# 14      161.1       52.5               17.8
# 15      209.7       85.7               18.4
# 16      146.4       41.3               16.5
# 17      144.0       51.7               16.3
# 18      232.6       89.6               18.1
# 19      224.1       82.7               19.1
# ...

# %%
data.corr()
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", linewidths=.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
data.corr()
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", linewidths=.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
data_X = data[["bmi_index","blood_sugar_level"]]
data_y = data["body_mass"]

# %%
train_X, test_X, train_y, teat_y = tts(data_X, data_y, test_size = 0.2,random_state=42)
model = ols(formula='body_mass ~ bmi_index + blood_sugar_level', data=data).fit()
print(model.summary())
from statsmodels.stats.anova import anova_lm
anova_table = anova_lm(model)
print("\nANOVA Table:")
print(anova_table)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              body_mass   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     101.9
# Date:                Tue, 09 Jan 2024   Prob (F-statistic):           1.52e-10
# Time:                        12:47:37   Log-Likelihood:                -78.178
# No. Observations:                  21   AIC:                             162.4
# Df Residuals:                      18   BIC:                             165.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -58.7968     58.965     -0.997      0.332    -182.677      65.084
# ...

# %% [markdown]
# The regresiion Model is:
# body_mass(y)=Bo+B1(bmi_index)+B2(bllod_sugar_level)+E
# body_mass(y)=-58.7968+1.4795(bmi_index)+8.6719(bsi)
